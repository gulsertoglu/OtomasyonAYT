# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


try:
    data = pd.read_csv('analiz_sonucu.json')
    print("Veri başarıyla yüklendi.")
except FileNotFoundError:
    print("HATA: 'analiz_sonucu.json' dosyası bulunamadı. Lütfen dosyanın 'MP4' klasöründe olduğundan emin olun.")

# İlk 5 satırı görüntüleyerek veriye hızlıca göz atın
print("\n--- Veri Setinin İlk 5 Satırı ---")
print(data.head())
# Out:
# Running cells with '.venv (Python 3.12.12)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/CASPER/Documents/OtomasyonSpotify/.venv/bin/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
#Temel İstatistikler 2. Kod bloğu;
print("\n--- Temel İstatistikler (Mean, Median, Std, vb.) ---")
print(data.describe())

# %%
#Eksik veri kontrolü 3. Kod bloğu; 
print("\n--- Eksik Veri Kontrolü ---")
print(data.isnull().sum())

# %%
#Korelasyon matrisi 4. Kod bloğu ;
print("\n--- Korelasyon Matrisi ---")
print(data.corr())
